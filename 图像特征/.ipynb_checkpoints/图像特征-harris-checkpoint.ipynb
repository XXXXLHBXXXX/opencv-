# %% [markdown]
# ### 图像特征-harris角点检测

# %% [markdown]
# ![title](harris_1.png)

# %% [markdown]
# #### 基本原理

# %% [markdown]
# ![title](harris_2.png)

# %% [markdown]
# ![title](harris_9.png)

# %% [markdown]
# ![title](harris_4.png)

# %% [markdown]
# ![title](harris_5.png)

# %% [markdown]
# ![title](harris_6.png)

# %% [markdown]
# ![title](harris_11.png)

# %% [markdown]
# #### cv2.cornerHarris()
# - img： 数据类型为 ﬂoat32 的入图像
# - blockSize： 角点检测中指定区域的大小
# - ksize： Sobel求导中使用的窗口大小
# - k： 取值参数为 [0,04,0.06]

# %%
import cv2 
import numpy as np

img = cv2.imread('test_1.jpg')
print ('img.shape:',img.shape)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# gray = np.float32(gray)
dst = cv2.cornerHarris(gray, 2, 3, 0.06)
print ('dst.shape:',dst.shape)
img[dst>0.1*dst.max()]=[0,0,255]
cv2.imshow('dst',img) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
# Out:
# img.shape: (800, 1200, 3)
# dst.shape: (800, 1200)

# %% [markdown]
# # 手写Harris角点检测

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import filters
def compute_harris_response(im, sigma = 3):
    """在一幅灰度图中，对每一个像素计算Harris角点检测器响应函数"""
    #计算Sobel偏导数
    imx = np.zeros(im.shape)
    filters.gaussian_filter(im,(sigma,sigma),(0,1),imx)
    imy = np.zeros(im.shape)
    filters.gaussian_filter(im,(sigma,sigma),(1,0),imy)
    #计算Harris矩阵分量
    Wxx = filters.gaussian_filter(imx * imx, sigma)
    Wxy = filters.gaussian_filter(imx * imy, sigma)
    Wyy = filters.gaussian_filter(imy * imy, sigma)

    #计算特征值和矩阵的迹
    Wdet = Wxx * Wyy - Wxy ** 2
    Wtr = Wxx + Wyy
    return Wdet / Wtr

def get_harris_points(harrisim, min_dist = 10, threshold = 0.5):
    """从一幅harris响应图像中返回角点。min_dist为分割角点和图像边界的最少像素数目"""
    #寻找高于阈值的候选角点
    corner_threshold = harrisim.max() * threshold
    harrisim_t = (harrisim > corner_threshold) * 1

    #得到候选点的坐标
    coords = np.array(harrisim_t.nonzero()).T
    #Harris响应值
    candidate_values = [harrisim[c[0],c[1]] for c in coords]
    #对候选点依照harris响应值进行排序
    index = np.argsort(candidate_values)
    #将可行点的位置保存到数值
    allowed_locations = np.zeros(harrisim.shape)
    allowed_locations[min_dist: -min_dist, min_dist:-min_dist] = 1

    #按照min_distance原则，选择最佳harris点
    filtered_coords = []
    for i in index:
        if allowed_locations[coords[i,0],coords[i,1]] == 1:
            filtered_coords.append(coords[i])
            allowed_locations[(coords[i,0]-min_dist):(coords[i,0]+min_dist),
            (coords[i,1]-min_dist):(coords[i,1]+min_dist)] = 0
    return filtered_coords

def plot_harris_points(image, filtered_coords):
    """绘制图像中检测的角点"""
    plt.figure()
    plt.gray()
    plt.imshow(image)
    plt.plot([p[1] for p in filtered_coords],[p[0] for p in filtered_coords],'*')
    plt.axis('off')
    plt.show()


img = cv2.imread('test_1.jpg')
im = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
harrisim = compute_harris_response(im)
filtered_coords = get_harris_points(harrisim,3)
plot_harris_points(im, filtered_coords)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-cff99f878f58> in <module>
#      60 filtered_coords = get_harris_points(harrisim,3)
#      61 plot_harris_points(im, filtered_coords)
# ---> 62 cv2.imshow('plot_harris_points',plot_harris_points)
#      63 cv2.waitKey(0)
#      64 cv2.destroyAllWindows()
#
# TypeError: Expected Ptr<cv::UMat> for argument 'mat'
